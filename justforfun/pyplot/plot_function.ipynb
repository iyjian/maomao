# %%
import matplotlib.pyplot as plt
import math

def my_range(start, end, step ,f):
  if ((start - end) * step) >= 0:
    print('error : your start end or step is not right') 
    raise ValueError
  result = []
  result2 = []
  current = start
  while current < end:
    result.append(current)
    result2.append(f(current))
    current += step
  return [result, result2]

def plot(f, rangex, rangey, step):
  plt.plot(*my_range(rangex, rangey, step, f)) 
  plt.show()

# %%
def f2(x):
  return x ** 2

# %%
plot(math.sqrt, 0, 10000, 0.001)
